# %% [markdown]
# <a href="https://colab.research.google.com/github/alanrojas-collab/Actividades-de-Programacion/blob/main/red_n_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.1/112.6 GB disk)

# %%
# !unzip "/content/datasets/dataset.zip" -d /content/datasets
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   inflating: /content/datasets/Entrenamiento/images/train/3u3da6nmtv59sn4sd5igkojtv.jpg
#   inflating: /content/datasets/Entrenamiento/images/train/3_1_2.jpg
#   inflating: /content/datasets/Entrenamiento/images/train/4379838_1676148402086_193.jpg
#   inflating: /content/datasets/Entrenamiento/images/train/450_1000.jpeg
#   inflating: /content/datasets/Entrenamiento/images/train/450_1000.jpg
#   inflating: /content/datasets/Entrenamiento/images/train/450_10002 (2).jpg
#   inflating: /content/datasets/Entrenamiento/images/train/450_10002.jpg
#   inflating: /content/datasets/Entrenamiento/images/train/450_10003.jpg
#   inflating: /content/datasets/Entrenamiento/images/train/465html-motociclistas-jpgjpeg-8858html-80f055ad-a62f-4744-9e02-7d9a94eb1923.jpeg
#   inflating: /content/datasets/Entrenamiento/images/train/4829936.jpg
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
